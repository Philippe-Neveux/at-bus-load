# %%
from datetime import date
import requests
from typing import Dict

from loguru import logger
import polars as pl

today = date.today().strftime("%Y-%m-%d")

# %% [markdown]
# # GTFS DATA

# %%
def get_at_gtfs_data_from_at_mobile_api(
    data_name: str,
    params: Dict[str, str | int] = {},
    headers: Dict[str, str | int] = {}
) -> pl.DataFrame:
    
    url = f"https://api.at.govt.nz/gtfs/v3/{data_name}"
    
    response = requests.get(
        url,
        params=params, 
        headers=headers
    )
    
    # logger.info(f"Request URL: {response.url}")
    if response.status_code != 200:
        logger.error(f"Request failed with status code {response.status_code}: {response.text}")
    
    data = response.json()
    if "data" not in data:
        logger.error("Expected 'data' key in the JSON response")
    
    json_data = data["data"]

    # Load data into Polars DataFrame
    df = pl.DataFrame(json_data)
    
    for col, dtype in df.schema.items():
        if isinstance(dtype, pl.datatypes.Struct):
            df = df.unnest(col)
            
    return df

# %% [markdown]
# ## Stops data

# %%
df_stops = get_at_gtfs_data_from_at_mobile_api(
    data_name="stops",
    params={
        "filter[date]": today
    },
    headers = {
        "Cache-Control": "no-cache",
        "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
    }
)
display(df_stops)
# Out:
# shape: (6_813, 11)
# ┌──────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬────────────┬───────────┐
# │ type ┆ id         ┆ location_t ┆ parent_sta ┆ … ┆ stop_lat  ┆ stop_lon  ┆ stop_name  ┆ wheelchai │
# │ ---  ┆ ---        ┆ ype        ┆ tion       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ r_boardin │
# │ str  ┆ str        ┆ ---        ┆ ---        ┆   ┆ f64       ┆ f64       ┆ str        ┆ g         │
# │      ┆            ┆ i64        ┆ str        ┆   ┆           ┆           ┆            ┆ ---       │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆            ┆ i64       │
# ╞══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪════════════╪═══════════╡
# │ stop ┆ 100-56c578 ┆ 1          ┆ null       ┆ … ┆ -36.97766 ┆ 174.84925 ┆ Papatoetoe ┆ 0         │
# │      ┆ 97         ┆            ┆            ┆   ┆           ┆           ┆ Train      ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Station    ┆           │
# │ stop ┆ 1002-c8bb8 ┆ 0          ┆ 31986-b1e9 ┆ … ┆ -36.84316 ┆ 174.76576 ┆ Stop A     ┆ 0         │
# │      ┆ 209        ┆            ┆ 5b83       ┆   ┆           ┆           ┆ Lower      ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Albert     ┆           │
# │ stop ┆ 1003-ea94d ┆ 0          ┆ 31986-b1e9 ┆ … ┆ -36.84381 ┆ 174.76551 ┆ Stop B     ┆ 0         │
# │      ┆ 2b2        ┆            ┆ 5b83       ┆   ┆           ┆           ┆ Lower      ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Albert     ┆           │
# │ stop ┆ 10036-2889 ┆ 1          ┆ null       ┆ … ┆ -36.89726 ┆ 174.80712 ┆ Ellerslie  ┆ 0         │
# │      ┆ 16d9       ┆            ┆            ┆   ┆           ┆           ┆            ┆           │
# │ stop ┆ 1004-42737 ┆ 0          ┆ 31986-b1e9 ┆ … ┆ -36.84403 ┆ 174.7655  ┆ Stop C     ┆ 0         │
# │      ┆ 000        ┆            ┆ 5b83       ┆   ┆           ┆           ┆ Lower      ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Albert     ┆           │
# │ …    ┆ …          ┆ …          ┆ …          ┆ … ┆ …         ┆ …         ┆ …          ┆ …         │
# │ stop ┆ 9925-fa861 ┆ 0          ┆ null       ┆ … ┆ -36.85073 ┆ 174.75679 ┆ Sam        ┆ 0         │
# │      ┆ 1dc        ┆            ┆            ┆   ┆           ┆           ┆ Wrigley    ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Street/    ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Cook       ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Stree…     ┆           │
# │ stop ┆ 9974-6b1dd ┆ 0          ┆ null       ┆ … ┆ -36.75943 ┆ 174.74654 ┆ Madison    ┆ 0         │
# │      ┆ 4cc        ┆            ┆            ┆   ┆           ┆           ┆ Place      ┆           │
# │ stop ┆ 9975-9f7b8 ┆ 0          ┆ null       ┆ … ┆ -36.75716 ┆ 174.74401 ┆ Linwood    ┆ 0         │
# │      ┆ faa        ┆            ┆            ┆   ┆           ┆           ┆ Avenue     ┆           │
# │ stop ┆ 9976-57a74 ┆ 0          ┆ null       ┆ … ┆ -36.75667 ┆ 174.74761 ┆ Linwood    ┆ 0         │
# │      ┆ 82e        ┆            ┆            ┆   ┆           ┆           ┆ Avenue     ┆           │
# │ stop ┆ 9986-e705d ┆ 0          ┆ null       ┆ … ┆ -36.39619 ┆ 174.66156 ┆ Matakana   ┆ 0         │
# │      ┆ d1d        ┆            ┆            ┆   ┆           ┆           ┆ Road       ┆           │
# └──────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴────────────┴───────────┘

# %%
df_stops.filter(pl.col("stop_name") == "Pitt Street").select(
    "stop_id",
    "stop_code",
).to_dict(as_series=False)
# Out:
# {'stop_id': ['7130-50c017db', '7133-173774ea'], 'stop_code': ['7130', '7133']}

# %%
df_stops.filter(pl.col("stop_name") == "Pitt Street")["id"].to_list()[0]
# Out:
# '7130-50c017db'

# %%
display(df_stops.filter(pl.col("stop_name") == "Bullock Track"))
# Out:
# shape: (2, 11)
# ┌──────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬────────────┬───────────┐
# │ type ┆ id         ┆ location_t ┆ parent_sta ┆ … ┆ stop_lat  ┆ stop_lon  ┆ stop_name  ┆ wheelchai │
# │ ---  ┆ ---        ┆ ype        ┆ tion       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ r_boardin │
# │ str  ┆ str        ┆ ---        ┆ ---        ┆   ┆ f64       ┆ f64       ┆ str        ┆ g         │
# │      ┆            ┆ i64        ┆ str        ┆   ┆           ┆           ┆            ┆ ---       │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆            ┆ i64       │
# ╞══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪════════════╪═══════════╡
# │ stop ┆ 8119-e41c6 ┆ 0          ┆ null       ┆ … ┆ -36.86614 ┆ 174.73094 ┆ Bullock    ┆ 0         │
# │      ┆ 252        ┆            ┆            ┆   ┆           ┆           ┆ Track      ┆           │
# │ stop ┆ 8120-1485c ┆ 0          ┆ null       ┆ … ┆ -36.86631 ┆ 174.73101 ┆ Bullock    ┆ 0         │
# │      ┆ c06        ┆            ┆            ┆   ┆           ┆           ┆ Track      ┆           │
# └──────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴────────────┴───────────┘

# %% [markdown]
# ## Routes data

# %%
df_routes = get_at_gtfs_data_from_at_mobile_api(
    data_name="routes",
    headers = {
        "Cache-Control": "no-cache",
        "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
    }
)

# %%
display(df_routes)
# Out:
# shape: (528, 9)
# ┌───────┬──────────┬───────────┬────────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ type  ┆ id       ┆ agency_id ┆ route_colo ┆ … ┆ route_long ┆ route_shor ┆ route_text ┆ route_typ │
# │ ---   ┆ ---      ┆ ---       ┆ r          ┆   ┆ _name      ┆ t_name     ┆ _color     ┆ e         │
# │ str   ┆ str      ┆ str       ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │       ┆          ┆           ┆ str        ┆   ┆ str        ┆ str        ┆ str        ┆ i64       │
# ╞═══════╪══════════╪═══════════╪════════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ route ┆ 101-202  ┆ NZB       ┆ null       ┆ … ┆ 101        ┆ 101        ┆ null       ┆ 3         │
# │ route ┆ 186-203  ┆ RTH       ┆ null       ┆ … ┆ 186        ┆ 186        ┆ null       ┆ 3         │
# │ route ┆ 191-203  ┆ RTH       ┆ null       ┆ … ┆ 191        ┆ 191        ┆ null       ┆ 3         │
# │ route ┆ 195-203  ┆ RTH       ┆ null       ┆ … ┆ 195        ┆ 195        ┆ null       ┆ 3         │
# │ route ┆ WX1-207  ┆ TZG       ┆ null       ┆ … ┆ WX1        ┆ WX1        ┆ null       ┆ 3         │
# │ …     ┆ …        ┆ …         ┆ …          ┆ … ┆ …          ┆ …          ┆ …          ┆ …         │
# │ route ┆ S813-202 ┆ NZB       ┆ null       ┆ … ┆ S813       ┆ 813        ┆ null       ┆ 712       │
# │ route ┆ STH-201  ┆ AM        ┆ D52923     ┆ … ┆ STH        ┆ STH        ┆ FFFFFF     ┆ 2         │
# │ route ┆ TMK-202  ┆ NZB       ┆ 007AB8     ┆ … ┆ TMK        ┆ TMK        ┆ FFFFFF     ┆ 3         │
# │ route ┆ WEST-201 ┆ AM        ┆ 97C93D     ┆ … ┆ WEST       ┆ WEST       ┆ 152239     ┆ 2         │
# │ route ┆ WSTH-211 ┆ BFL       ┆ 00B1BF     ┆ … ┆ WSTH       ┆ WSTH       ┆ 152239     ┆ 4         │
# └───────┴──────────┴───────────┴────────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
display(df_routes.filter(pl.col("route_short_name") == "18"))
# Out:
# shape: (1, 9)
# ┌───────┬────────┬───────────┬─────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ type  ┆ id     ┆ agency_id ┆ route_color ┆ … ┆ route_long ┆ route_shor ┆ route_text ┆ route_type │
# │ ---   ┆ ---    ┆ ---       ┆ ---         ┆   ┆ _name      ┆ t_name     ┆ _color     ┆ ---        │
# │ str   ┆ str    ┆ str       ┆ str         ┆   ┆ ---        ┆ ---        ┆ ---        ┆ i64        │
# │       ┆        ┆           ┆             ┆   ┆ str        ┆ str        ┆ str        ┆            │
# ╞═══════╪════════╪═══════════╪═════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ route ┆ 18-202 ┆ NZB       ┆ null        ┆ … ┆ 18         ┆ 18         ┆ null       ┆ 3          │
# └───────┴────────┴───────────┴─────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# ## Trips by route ID

# %%
df_trips_by_route = get_at_gtfs_data_from_at_mobile_api(
    data_name="routes/S025-203/trips",
    headers = {
        "Cache-Control": "no-cache",
        "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
    }
)

# %%
display(df_trips_by_route)
# Out:
# shape: (1, 10)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ type ┆ id         ┆ bikes_allo ┆ direction_ ┆ … ┆ shape_id   ┆ trip_head ┆ trip_id   ┆ wheelchai │
# │ ---  ┆ ---        ┆ wed        ┆ id         ┆   ┆ ---        ┆ sign      ┆ ---       ┆ r_accessi │
# │ str  ┆ str        ┆ ---        ┆ ---        ┆   ┆ str        ┆ ---       ┆ str       ┆ ble       │
# │      ┆            ┆ i64        ┆ i64        ┆   ┆            ┆ str       ┆           ┆ ---       │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆           ┆ i64       │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ trip ┆ 275-02568- ┆ 0          ┆ 1          ┆ … ┆ 275-02568- ┆ Westlake  ┆ 275-02568 ┆ 0         │
# │      ┆ 55500-2-32 ┆            ┆            ┆   ┆ 27dcc78e   ┆ Schools   ┆ -55500-2- ┆           │
# │      ┆ 122e7b     ┆            ┆            ┆   ┆            ┆ To Torbay ┆ 32122e7b  ┆           │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Stoptimes by trip ID

# %%
df_stopstimes_by_trip_id = get_at_gtfs_data_from_at_mobile_api(
    data_name="trips/1153-07005-51600-2-e7801de1/stoptimes",
    headers = {
        "Cache-Control": "no-cache",
        "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
    }
)

# %%
display(
    df_stopstimes_by_trip_id
    .join(
        df_stops.select("id", "stop_name"),
        left_on="stop_id",
        right_on="id",
        how="left"
    )
)
# Out:
# shape: (43, 13)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ type     ┆ id        ┆ arrival_t ┆ departure ┆ … ┆ stop_sequ ┆ timepoint ┆ trip_id   ┆ stop_name │
# │ ---      ┆ ---       ┆ ime       ┆ _time     ┆   ┆ ence      ┆ ---       ┆ ---       ┆ ---       │
# │ str      ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ i64       ┆ str       ┆ str       │
# │          ┆           ┆ str       ┆ str       ┆   ┆ i64       ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ stoptime ┆ 1153-0700 ┆ 14:20:00  ┆ 14:20:00  ┆ … ┆ 1         ┆ 0         ┆ 1153-0700 ┆ Stop A    │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ Botany    │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆ Town      │
# │          ┆ _1        ┆           ┆           ┆   ┆           ┆           ┆           ┆ Centre    │
# │ stoptime ┆ 1153-0700 ┆ 14:21:11  ┆ 14:21:11  ┆ … ┆ 2         ┆ 0         ┆ 1153-0700 ┆ Woolworth │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ s Botany  │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆           │
# │          ┆ _2        ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ stoptime ┆ 1153-0700 ┆ 14:22:05  ┆ 14:22:05  ┆ … ┆ 3         ┆ 0         ┆ 1153-0700 ┆ The Hub   │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆           │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆           │
# │          ┆ _3        ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ stoptime ┆ 1153-0700 ┆ 14:23:28  ┆ 14:23:28  ┆ … ┆ 4         ┆ 0         ┆ 1153-0700 ┆ Burswood  │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ Drive     │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆           │
# │          ┆ _4        ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ stoptime ┆ 1153-0700 ┆ 14:24:31  ┆ 14:24:31  ┆ … ┆ 5         ┆ 0         ┆ 1153-0700 ┆ Harris    │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ Road      │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆           │
# │          ┆ _5        ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ stoptime ┆ 1153-0700 ┆ 15:22:34  ┆ 15:22:34  ┆ … ┆ 39        ┆ 0         ┆ 1153-0700 ┆ Symonds   │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ Street/Ka │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆ rangahape │
# │          ┆ _39       ┆           ┆           ┆   ┆           ┆           ┆           ┆ Roa…      │
# │ stoptime ┆ 1153-0700 ┆ 15:24:48  ┆ 15:24:48  ┆ … ┆ 40        ┆ 0         ┆ 1153-0700 ┆ Stop E    │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ Auckland  │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆ Universit │
# │          ┆ _40       ┆           ┆           ┆   ┆           ┆           ┆           ┆ ies       │
# │ stoptime ┆ 1153-0700 ┆ 15:27:15  ┆ 15:27:15  ┆ … ┆ 41        ┆ 0         ┆ 1153-0700 ┆ Waterloo  │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ Quadrant  │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆           │
# │          ┆ _41       ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ stoptime ┆ 1153-0700 ┆ 15:30:12  ┆ 15:30:12  ┆ … ┆ 42        ┆ 0         ┆ 1153-0700 ┆ Anzac Ave │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ nue/Beach │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆ Road      │
# │          ┆ _42       ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ stoptime ┆ 1153-0700 ┆ 15:35:00  ┆ 15:35:00  ┆ … ┆ 43        ┆ 0         ┆ 1153-0700 ┆ Britomart │
# │          ┆ 5-51600-2 ┆           ┆           ┆   ┆           ┆           ┆ 5-51600-2 ┆ Commerce  │
# │          ┆ -e7801de1 ┆           ┆           ┆   ┆           ┆           ┆ -e7801de1 ┆ Street    │
# │          ┆ _43       ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Stop trips by Stop id

# %%
df_stop_trips_by_stop_id = get_at_gtfs_data_from_at_mobile_api(
    data_name="stops/7133-173774ea/stoptrips",
    params={
        "filter[date]": "2025-06-15",
        "filter[start_hour]": 7,
        "filter[hour_range]": 15
    },
    headers = {
        "Cache-Control": "no-cache",
        "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
    }
)
# https://api.at.govt.nz/gtfs/v3/stops/8119-e41c6252/stoptrips?filter[date]=2025-06-14&filter[start_hour]=8&filter%5Bhour_range%5D=5

# df_stop_trips_by_stop_id["route_id"].unique()

display(df_stop_trips_by_stop_id)
# Out:
# shape: (246, 16)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ type     ┆ id        ┆ arrival_t ┆ departure ┆ … ┆ stop_sequ ┆ trip_head ┆ trip_id   ┆ trip_star │
# │ ---      ┆ ---       ┆ ime       ┆ _time     ┆   ┆ ence      ┆ sign      ┆ ---       ┆ t_time    │
# │ str      ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ str       ┆ ---       │
# │          ┆           ┆ str       ┆ str       ┆   ┆ i64       ┆ str       ┆           ┆ str       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ stoptrip ┆ stop:7133 ┆ 07:08:11  ┆ 07:08:11  ┆ … ┆ 34        ┆ Northwest ┆ 1222-0110 ┆ 06:26:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-23160-2 ┆           │
# │          ┆ _trip:122 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -c7765123 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via W…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 07:12:51  ┆ 07:12:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 06:45:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-24300-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 07:13:17  ┆ 07:13:17  ┆ … ┆ 27        ┆ New Lynn  ┆ 1075-0180 ┆ 06:45:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-24300-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -d1ba66eb ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 07:25:49  ┆ 07:25:49  ┆ … ┆ 29        ┆ Northwest ┆ 1203-0110 ┆ 06:45:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 5-24300-2 ┆           │
# │          ┆ _trip:120 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -77683a6f ┆           │
# │          ┆ 3-0…      ┆           ┆           ┆   ┆           ┆ Via T…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 07:27:51  ┆ 07:27:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 07:00:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-25200-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ stoptrip ┆ stop:7133 ┆ 21:36:47  ┆ 21:36:47  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 21:00:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-75600-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -9b98cbc4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 21:38:11  ┆ 21:38:11  ┆ … ┆ 34        ┆ Northwest ┆ 1222-0110 ┆ 20:56:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-75360-2 ┆           │
# │          ┆ _trip:122 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -c7765123 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via W…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 21:45:56  ┆ 21:45:56  ┆ … ┆ 27        ┆ New Lynn  ┆ 1075-0180 ┆ 21:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-76500-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -975633d0 ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 21:51:47  ┆ 21:51:47  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 21:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-76500-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -9b98cbc4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 21:53:11  ┆ 21:53:11  ┆ … ┆ 29        ┆ Northwest ┆ 1203-0110 ┆ 21:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 5-76500-2 ┆           │
# │          ┆ _trip:120 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -59399ba1 ┆           │
# │          ┆ 3-0…      ┆           ┆           ┆   ┆           ┆ Via T…    ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Calendar per Service ID

# %%
service_IDs = df_trips_by_route.select("service_id").unique().to_series().to_list()

dfs = []

for service_id in service_IDs:
    df_calendars = get_at_gtfs_data_from_at_mobile_api(
        data_name=f"services/{service_id}/calendars",
        headers = {
            "Cache-Control": "no-cache",
            "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
        }
    )
    dfs.append(df_calendars)
    
df_calendars_by_service = pl.concat(dfs)

display(df_calendars_by_service)
# Out:
# shape: (1, 12)
# ┌──────────┬───────────┬────────────┬────────┬───┬────────┬──────────┬─────────┬───────────┐
# │ type     ┆ id        ┆ end_date   ┆ friday ┆ … ┆ sunday ┆ thursday ┆ tuesday ┆ wednesday │
# │ ---      ┆ ---       ┆ ---        ┆ ---    ┆   ┆ ---    ┆ ---      ┆ ---     ┆ ---       │
# │ str      ┆ str       ┆ str        ┆ i64    ┆   ┆ i64    ┆ i64      ┆ i64     ┆ i64       │
# ╞══════════╪═══════════╪════════════╪════════╪═══╪════════╪══════════╪═════════╪═══════════╡
# │ calendar ┆ Weekday-4 ┆ 2025-09-28 ┆ 1      ┆ … ┆ 0      ┆ 1        ┆ 1       ┆ 1         │
# └──────────┴───────────┴────────────┴────────┴───┴────────┴──────────┴─────────┴───────────┘

# %% [markdown]
# # extract Avondale -> Sagrado Cantina

# %%
stop_codes = [
    "8147",
    "8545",
    "7149",
    "8331",
    "7133"
]

df_stops_av_sc = (
    df_stops
    .filter(
        pl.col("stop_code")
        .is_in(stop_codes)
    )
)
display(df_stops_av_sc)
# Out:
# shape: (5, 11)
# ┌──────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬────────────┬───────────┐
# │ type ┆ id         ┆ location_t ┆ parent_sta ┆ … ┆ stop_lat  ┆ stop_lon  ┆ stop_name  ┆ wheelchai │
# │ ---  ┆ ---        ┆ ype        ┆ tion       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ r_boardin │
# │ str  ┆ str        ┆ ---        ┆ ---        ┆   ┆ f64       ┆ f64       ┆ str        ┆ g         │
# │      ┆            ┆ i64        ┆ str        ┆   ┆           ┆           ┆            ┆ ---       │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆            ┆ i64       │
# ╞══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪════════════╪═══════════╡
# │ stop ┆ 7133-17377 ┆ 0          ┆ null       ┆ … ┆ -36.85773 ┆ 174.75968 ┆ Pitt       ┆ 0         │
# │      ┆ 4ea        ┆            ┆            ┆   ┆           ┆           ┆ Street     ┆           │
# │ stop ┆ 7149-6d6d1 ┆ 0          ┆ null       ┆ … ┆ -36.85741 ┆ 174.76449 ┆ Symonds    ┆ 0         │
# │      ┆ e99        ┆            ┆            ┆   ┆           ┆           ┆ Street/Kar ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ angahape   ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Roa…       ┆           │
# │ stop ┆ 8147-58c87 ┆ 0          ┆ null       ┆ … ┆ -36.89337 ┆ 174.69607 ┆ Avondale   ┆ 0         │
# │      ┆ 2f4        ┆            ┆            ┆   ┆           ┆           ┆ Police     ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Station    ┆           │
# │ stop ┆ 8331-c2dad ┆ 0          ┆ null       ┆ … ┆ -36.89569 ┆ 174.70094 ┆ Avondale   ┆ 0         │
# │      ┆ 3f5        ┆            ┆            ┆   ┆           ┆           ┆ Islamic    ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ Centre     ┆           │
# │ stop ┆ 8545-aed7c ┆ 0          ┆ null       ┆ … ┆ -36.89247 ┆ 174.68973 ┆ Rosebank   ┆ 0         │
# │      ┆ 410        ┆            ┆            ┆   ┆           ┆           ┆ Road/Victo ┆           │
# │      ┆            ┆            ┆            ┆   ┆           ┆           ┆ r Street   ┆           │
# └──────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴────────────┴───────────┘

# %%
df_stops_av_sc["id"].to_list()
# Out:
# ['7133-173774ea',
#  '7149-6d6d1e99',
#  '8147-58c872f4',
#  '8331-c2dad3f5',
#  '8545-aed7c410']

# %%
stop_ids = df_stops_av_sc["id"].to_list()
dates = [
    "2025-06-09",
    "2025-06-10",
    "2025-06-11",
    "2025-06-12",
    "2025-06-13",
    "2025-06-14",
    "2025-06-15",
    "2025-06-16"
]

trips_av_sc = []

for stop_id in stop_ids:
    for api_date in dates:
        logger.info(f"Fetching trips for stop {stop_id} on date {api_date}")
        df_trips = get_at_gtfs_data_from_at_mobile_api(
            data_name=f"stops/{stop_id}/stoptrips",
            params={
                "filter[date]": date,
                "filter[start_hour]": 3,
                "filter[hour_range]": 24
            },
            headers = {
                "Cache-Control": "no-cache",
                "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
            }
        )
        trips_av_sc.append(df_trips)
    
df_trips_av_sc_api = pl.concat(trips_av_sc)
display(df_trips_av_sc_api)
# Out:
# 2025-06-18 13:27:23.167 | INFO     | __main__:<module>:17 - Fetching trips for stop 7133-173774ea on date 2025-06-09
# 2025-06-18 13:27:23.605 | INFO     | __main__:<module>:17 - Fetching trips for stop 7133-173774ea on date 2025-06-10
# 2025-06-18 13:27:23.953 | INFO     | __main__:<module>:17 - Fetching trips for stop 7133-173774ea on date 2025-06-11
# 2025-06-18 13:27:24.314 | INFO     | __main__:<module>:17 - Fetching trips for stop 7133-173774ea on date 2025-06-12
# 2025-06-18 13:27:24.656 | INFO     | __main__:<module>:17 - Fetching trips for stop 7133-173774ea on date 2025-06-13
# 2025-06-18 13:27:25.006 | INFO     | __main__:<module>:17 - Fetching trips for stop 7133-173774ea on date 2025-06-14
# 2025-06-18 13:27:25.345 | INFO     | __main__:<module>:17 - Fetching trips for stop 7133-173774ea on date 2025-06-15
# 2025-06-18 13:27:25.674 | INFO     | __main__:<module>:17 - Fetching trips for stop 7133-173774ea on date 2025-06-16
# 2025-06-18 13:27:26.184 | INFO     | __main__:<module>:17 - Fetching trips for stop 7149-6d6d1e99 on date 2025-06-09
# 2025-06-18 13:27:26.798 | INFO     | __main__:<module>:17 - Fetching trips for stop 7149-6d6d1e99 on date 2025-06-10
# 2025-06-18 13:27:27.443 | INFO     | __main__:<module>:17 - Fetching trips for stop 7149-6d6d1e99 on date 2025-06-11
# 2025-06-18 13:27:28.048 | INFO     | __main__:<module>:17 - Fetching trips for stop 7149-6d6d1e99 on date 2025-06-12
# 2025-06-18 13:27:28.698 | INFO     | __main__:<module>:17 - Fetching trips for stop 7149-6d6d1e99 on date 2025-06-13
# 2025-06-18 13:27:29.298 | INFO     | __main__:<module>:17 - Fetching trips for stop 7149-6d6d1e99 on date 2025-06-14
# 2025-06-18 13:27:29.754 | INFO     | __main__:<module>:17 - Fetching trips for stop 7149-6d6d1e99 on date 2025-06-15
# 2025-06-18 13:27:30.203 | INFO     | __main__:<module>:17 - Fetching trips for stop 7149-6d6d1e99 on date 2025-06-16
# 2025-06-18 13:27:30.779 | INFO     | __main__:<module>:17 - Fetching trips for stop 8147-58c872f4 on date 2025-06-09
# 2025-06-18 13:27:31.018 | INFO     | __main__:<module>:17 - Fetching trips for stop 8147-58c872f4 on date 2025-06-10
# 2025-06-18 13:27:31.254 | INFO     | __main__:<module>:17 - Fetching trips for stop 8147-58c872f4 on date 2025-06-11
# 2025-06-18 13:27:31.493 | INFO     | __main__:<module>:17 - Fetching trips for stop 8147-58c872f4 on date 2025-06-12
# 2025-06-18 13:27:31.736 | INFO     | __main__:<module>:17 - Fetching trips for stop 8147-58c872f4 on date 2025-06-13
# 2025-06-18 13:27:31.948 | INFO     | __main__:<module>:17 - Fetching trips for stop 8147-58c872f4 on date 2025-06-14
# 2025-06-18 13:27:32.184 | INFO     | __main__:<module>:17 - Fetching trips for stop 8147-58c872f4 on date 2025-06-15
# 2025-06-18 13:27:32.419 | INFO     | __main__:<module>:17 - Fetching trips for stop 8147-58c872f4 on date 2025-06-16
# 2025-06-18 13:27:32.646 | INFO     | __main__:<module>:17 - Fetching trips for stop 8331-c2dad3f5 on date 2025-06-09
# 2025-06-18 13:27:32.977 | INFO     | __main__:<module>:17 - Fetching trips for stop 8331-c2dad3f5 on date 2025-06-10
# 2025-06-18 13:27:33.273 | INFO     | __main__:<module>:17 - Fetching trips for stop 8331-c2dad3f5 on date 2025-06-11
# 2025-06-18 13:27:33.592 | INFO     | __main__:<module>:17 - Fetching trips for stop 8331-c2dad3f5 on date 2025-06-12
# 2025-06-18 13:27:33.923 | INFO     | __main__:<module>:17 - Fetching trips for stop 8331-c2dad3f5 on date 2025-06-13
# 2025-06-18 13:27:34.272 | INFO     | __main__:<module>:17 - Fetching trips for stop 8331-c2dad3f5 on date 2025-06-14
# 2025-06-18 13:27:34.556 | INFO     | __main__:<module>:17 - Fetching trips for stop 8331-c2dad3f5 on date 2025-06-15
# 2025-06-18 13:27:34.857 | INFO     | __main__:<module>:17 - Fetching trips for stop 8331-c2dad3f5 on date 2025-06-16
# 2025-06-18 13:27:35.152 | INFO     | __main__:<module>:17 - Fetching trips for stop 8545-aed7c410 on date 2025-06-09
# 2025-06-18 13:27:35.381 | INFO     | __main__:<module>:17 - Fetching trips for stop 8545-aed7c410 on date 2025-06-10
# 2025-06-18 13:27:35.634 | INFO     | __main__:<module>:17 - Fetching trips for stop 8545-aed7c410 on date 2025-06-11
# 2025-06-18 13:27:35.849 | INFO     | __main__:<module>:17 - Fetching trips for stop 8545-aed7c410 on date 2025-06-12
# 2025-06-18 13:27:36.068 | INFO     | __main__:<module>:17 - Fetching trips for stop 8545-aed7c410 on date 2025-06-13
# 2025-06-18 13:27:36.313 | INFO     | __main__:<module>:17 - Fetching trips for stop 8545-aed7c410 on date 2025-06-14
# 2025-06-18 13:27:36.539 | INFO     | __main__:<module>:17 - Fetching trips for stop 8545-aed7c410 on date 2025-06-15
# 2025-06-18 13:27:36.742 | INFO     | __main__:<module>:17 - Fetching trips for stop 8545-aed7c410 on date 2025-06-16
# shape: (11_019, 16)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ type     ┆ id        ┆ arrival_t ┆ departure ┆ … ┆ stop_sequ ┆ trip_head ┆ trip_id   ┆ trip_star │
# │ ---      ┆ ---       ┆ ime       ┆ _time     ┆   ┆ ence      ┆ sign      ┆ ---       ┆ t_time    │
# │ str      ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ str       ┆ ---       │
# │          ┆           ┆ str       ┆ str       ┆   ┆ i64       ┆ str       ┆           ┆ str       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ stoptrip ┆ stop:7133 ┆ 05:26:31  ┆ 05:26:31  ┆ … ┆ 28        ┆ New Lynn  ┆ 1075-0180 ┆ 05:00:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-18000-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -a74f27ae ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:27:51  ┆ 05:27:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 05:00:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-18000-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:41:31  ┆ 05:41:31  ┆ … ┆ 28        ┆ New Lynn  ┆ 1075-0180 ┆ 05:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-18900-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -a74f27ae ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:50:33  ┆ 05:50:33  ┆ … ┆ 35        ┆ Northwest ┆ 1222-0110 ┆ 05:08:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-18480-2 ┆           │
# │          ┆ _trip:122 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -3f5e175f ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via W…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:56:33  ┆ 05:56:33  ┆ … ┆ 57        ┆ New Lynn  ┆ 1095-1950 ┆ 05:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-18900-2 ┆           │
# │          ┆ _trip:109 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -f1cd1a53 ┆           │
# │          ┆ 5-1…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ stoptrip ┆ stop:8545 ┆ 20:26:26  ┆ 20:26:26  ┆ … ┆ 12        ┆ Rosebank  ┆ 1278-0220 ┆ 20:21:00  │
# │          ┆ -aed7c410 ┆           ┆           ┆   ┆           ┆ Rd To     ┆ 1-73260-2 ┆           │
# │          ┆ _trip:127 ┆           ┆           ┆   ┆           ┆ City      ┆ -876d2346 ┆           │
# │          ┆ 8-0…      ┆           ┆           ┆   ┆           ┆ Centre    ┆           ┆           │
# │          ┆           ┆           ┆           ┆   ┆           ┆ Via…      ┆           ┆           │
# │ stoptrip ┆ stop:8545 ┆ 20:56:26  ┆ 20:56:26  ┆ … ┆ 12        ┆ Rosebank  ┆ 1278-0220 ┆ 20:51:00  │
# │          ┆ -aed7c410 ┆           ┆           ┆   ┆           ┆ Rd To     ┆ 1-75060-2 ┆           │
# │          ┆ _trip:127 ┆           ┆           ┆   ┆           ┆ City      ┆ -876d2346 ┆           │
# │          ┆ 8-0…      ┆           ┆           ┆   ┆           ┆ Centre    ┆           ┆           │
# │          ┆           ┆           ┆           ┆   ┆           ┆ Via…      ┆           ┆           │
# │ stoptrip ┆ stop:8545 ┆ 21:26:26  ┆ 21:26:26  ┆ … ┆ 12        ┆ Rosebank  ┆ 1278-0220 ┆ 21:21:00  │
# │          ┆ -aed7c410 ┆           ┆           ┆   ┆           ┆ Rd To     ┆ 1-76860-2 ┆           │
# │          ┆ _trip:127 ┆           ┆           ┆   ┆           ┆ City      ┆ -876d2346 ┆           │
# │          ┆ 8-0…      ┆           ┆           ┆   ┆           ┆ Centre    ┆           ┆           │
# │          ┆           ┆           ┆           ┆   ┆           ┆ Via…      ┆           ┆           │
# │ stoptrip ┆ stop:8545 ┆ 21:56:26  ┆ 21:56:26  ┆ … ┆ 12        ┆ Rosebank  ┆ 1278-0220 ┆ 21:51:00  │
# │          ┆ -aed7c410 ┆           ┆           ┆   ┆           ┆ Rd To     ┆ 1-78660-2 ┆           │
# │          ┆ _trip:127 ┆           ┆           ┆   ┆           ┆ City      ┆ -876d2346 ┆           │
# │          ┆ 8-0…      ┆           ┆           ┆   ┆           ┆ Centre    ┆           ┆           │
# │          ┆           ┆           ┆           ┆   ┆           ┆ Via…      ┆           ┆           │
# │ stoptrip ┆ stop:8545 ┆ 22:40:26  ┆ 22:40:26  ┆ … ┆ 12        ┆ Rosebank  ┆ 1278-0220 ┆ 22:35:00  │
# │          ┆ -aed7c410 ┆           ┆           ┆   ┆           ┆ Rd To     ┆ 1-81300-2 ┆           │
# │          ┆ _trip:127 ┆           ┆           ┆   ┆           ┆ City      ┆ -39bf8491 ┆           │
# │          ┆ 8-0…      ┆           ┆           ┆   ┆           ┆ Centre    ┆           ┆           │
# │          ┆           ┆           ┆           ┆   ┆           ┆ Via…      ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df_stop_date1 = get_at_gtfs_data_from_at_mobile_api(
        data_name="stops/7133-173774ea/stoptrips",
        params={
            "filter[date]": "2025-06-13",
            "filter[start_hour]": 3,
            "filter[hour_range]": 24
        },
        headers = {
            "Cache-Control": "no-cache",
            "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
        }
    ).sort("arrival_time")

df_stop_date2 = get_at_gtfs_data_from_at_mobile_api(
        data_name="stops/7133-173774ea/stoptrips",
        params={
            "filter[date]": "2025-06-16",
            "filter[start_hour]": 3,
            "filter[hour_range]": 24
        },
        headers = {
            "Cache-Control": "no-cache",
            "Ocp-Apim-Subscription-Key": "5d22b4c49b284b9b8ace5d1971819052"
        }
    ).sort("arrival_time")

# %%
df_stop_date1 == df_stop_date2
# Out:
# shape: (352, 16)
# ┌──────┬───────┬─────────────┬─────────────┬───┬─────────────┬─────────────┬─────────┬─────────────┐
# │ type ┆ id    ┆ arrival_tim ┆ departure_t ┆ … ┆ stop_sequen ┆ trip_headsi ┆ trip_id ┆ trip_start_ │
# │ ---  ┆ ---   ┆ e           ┆ ime         ┆   ┆ ce          ┆ gn          ┆ ---     ┆ time        │
# │ bool ┆ bool  ┆ ---         ┆ ---         ┆   ┆ ---         ┆ ---         ┆ bool    ┆ ---         │
# │      ┆       ┆ bool        ┆ bool        ┆   ┆ bool        ┆ bool        ┆         ┆ bool        │
# ╞══════╪═══════╪═════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════╪═════════════╡
# │ true ┆ false ┆ true        ┆ true        ┆ … ┆ false       ┆ true        ┆ false   ┆ true        │
# │ true ┆ true  ┆ true        ┆ true        ┆ … ┆ true        ┆ true        ┆ true    ┆ true        │
# │ true ┆ false ┆ true        ┆ true        ┆ … ┆ false       ┆ true        ┆ false   ┆ true        │
# │ true ┆ false ┆ false       ┆ false       ┆ … ┆ false       ┆ true        ┆ false   ┆ true        │
# │ true ┆ true  ┆ true        ┆ true        ┆ … ┆ true        ┆ true        ┆ true    ┆ true        │
# │ …    ┆ …     ┆ …           ┆ …           ┆ … ┆ …           ┆ …           ┆ …       ┆ …           │
# │ true ┆ false ┆ false       ┆ false       ┆ … ┆ false       ┆ false       ┆ false   ┆ false       │
# │ true ┆ false ┆ false       ┆ false       ┆ … ┆ false       ┆ false       ┆ false   ┆ false       │
# │ true ┆ false ┆ true        ┆ true        ┆ … ┆ false       ┆ true        ┆ false   ┆ true        │
# │ true ┆ false ┆ false       ┆ false       ┆ … ┆ false       ┆ false       ┆ false   ┆ false       │
# │ true ┆ false ┆ false       ┆ false       ┆ … ┆ false       ┆ false       ┆ false   ┆ false       │
# └──────┴───────┴─────────────┴─────────────┴───┴─────────────┴─────────────┴─────────┴─────────────┘

# %%
df_stop_date1
# Out:
# shape: (352, 16)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ type     ┆ id        ┆ arrival_t ┆ departure ┆ … ┆ stop_sequ ┆ trip_head ┆ trip_id   ┆ trip_star │
# │ ---      ┆ ---       ┆ ime       ┆ _time     ┆   ┆ ence      ┆ sign      ┆ ---       ┆ t_time    │
# │ str      ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ str       ┆ ---       │
# │          ┆           ┆ str       ┆ str       ┆   ┆ i64       ┆ str       ┆           ┆ str       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ stoptrip ┆ stop:7133 ┆ 05:26:31  ┆ 05:26:31  ┆ … ┆ 28        ┆ New Lynn  ┆ 1075-0180 ┆ 05:00:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-18000-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -a74f27ae ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:27:51  ┆ 05:27:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 05:00:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-18000-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:41:31  ┆ 05:41:31  ┆ … ┆ 28        ┆ New Lynn  ┆ 1075-0180 ┆ 05:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-18900-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -a74f27ae ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:50:33  ┆ 05:50:33  ┆ … ┆ 35        ┆ Northwest ┆ 1222-0110 ┆ 05:08:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-18480-2 ┆           │
# │          ┆ _trip:122 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -3f5e175f ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via W…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:56:33  ┆ 05:56:33  ┆ … ┆ 57        ┆ New Lynn  ┆ 1095-1950 ┆ 05:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-18900-2 ┆           │
# │          ┆ _trip:109 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -f1cd1a53 ┆           │
# │          ┆ 5-1…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ stoptrip ┆ stop:7133 ┆ 23:42:51  ┆ 23:42:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 23:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-83700-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 23:43:44  ┆ 23:43:44  ┆ … ┆ 35        ┆ Northwest ┆ 1222-0110 ┆ 22:58:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-82680-2 ┆           │
# │          ┆ _trip:122 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -559d62ad ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via W…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 23:45:56  ┆ 23:45:56  ┆ … ┆ 28        ┆ New Lynn  ┆ 1075-0180 ┆ 23:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-83700-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -d62d3b73 ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 23:57:51  ┆ 23:57:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 23:30:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-84600-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 23:58:51  ┆ 23:58:51  ┆ … ┆ 30        ┆ Northwest ┆ 1203-0110 ┆ 23:17:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 5-83820-2 ┆           │
# │          ┆ _trip:120 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -4eb5e7e8 ┆           │
# │          ┆ 3-0…      ┆           ┆           ┆   ┆           ┆ Via T…    ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df_stop_date2
# Out:
# shape: (352, 16)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ type     ┆ id        ┆ arrival_t ┆ departure ┆ … ┆ stop_sequ ┆ trip_head ┆ trip_id   ┆ trip_star │
# │ ---      ┆ ---       ┆ ime       ┆ _time     ┆   ┆ ence      ┆ sign      ┆ ---       ┆ t_time    │
# │ str      ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ str       ┆ ---       │
# │          ┆           ┆ str       ┆ str       ┆   ┆ i64       ┆ str       ┆           ┆ str       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ stoptrip ┆ stop:7133 ┆ 05:26:31  ┆ 05:26:31  ┆ … ┆ 27        ┆ New Lynn  ┆ 1075-0180 ┆ 05:00:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-18000-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -0909bf84 ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:27:51  ┆ 05:27:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 05:00:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-18000-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:41:31  ┆ 05:41:31  ┆ … ┆ 27        ┆ New Lynn  ┆ 1075-0180 ┆ 05:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-18900-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -0909bf84 ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:50:32  ┆ 05:50:32  ┆ … ┆ 34        ┆ Northwest ┆ 1222-0110 ┆ 05:08:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-18480-2 ┆           │
# │          ┆ _trip:122 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -ed4752e5 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via W…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 05:56:33  ┆ 05:56:33  ┆ … ┆ 57        ┆ New Lynn  ┆ 1095-1950 ┆ 05:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-18900-2 ┆           │
# │          ┆ _trip:109 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -f1cd1a53 ┆           │
# │          ┆ 5-1…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ stoptrip ┆ stop:7133 ┆ 23:40:11  ┆ 23:40:11  ┆ … ┆ 34        ┆ Northwest ┆ 1222-0110 ┆ 22:58:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 7-82680-2 ┆           │
# │          ┆ _trip:122 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -2cc162c0 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via W…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 23:42:51  ┆ 23:42:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 23:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-83700-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 23:45:56  ┆ 23:45:56  ┆ … ┆ 27        ┆ New Lynn  ┆ 1075-0180 ┆ 23:15:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 3-83700-2 ┆           │
# │          ┆ _trip:107 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -975633d0 ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆           ┆ Via Gr…   ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 23:55:18  ┆ 23:55:18  ┆ … ┆ 29        ┆ Northwest ┆ 1203-0110 ┆ 23:17:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 5-83820-2 ┆           │
# │          ┆ _trip:120 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8b367aed ┆           │
# │          ┆ 3-0…      ┆           ┆           ┆   ┆           ┆ Via T…    ┆           ┆           │
# │ stoptrip ┆ stop:7133 ┆ 23:57:51  ┆ 23:57:51  ┆ … ┆ 6         ┆ Northwest ┆ 1292-0100 ┆ 23:30:00  │
# │          ┆ -173774ea ┆           ┆           ┆   ┆           ┆ To City   ┆ 1-84600-2 ┆           │
# │          ┆ _trip:129 ┆           ┆           ┆   ┆           ┆ Centre    ┆ -8e3771d4 ┆           │
# │          ┆ 2-0…      ┆           ┆           ┆   ┆           ┆ Via M…    ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# remove trip without 2 stops in the same trip_id
# It means that the trip doesn't start at avondale or doesn't end at sagrida cantina

df_trips_av_sc_api = (
    df_trips_av_sc_api
    .join(
        df_trips_av_sc_api
        .group_by("trip_id", "service_date", "route_id")
        .len()
        .filter(pl.col("len") > 1)
        .drop("len"),
        on=["trip_id", "service_date", "route_id"],
        how="inner"
    )
    .filter(pl.col("route_id") != "191-203")
)
df_trips_av_sc_api["route_id"].unique()
# Out:
# shape: (3,)
# Series: 'route_id' [str]
# [
# 	"195-203"
# 	"22R-202"
# 	"18-202"
# ]

# %%
df_trips_av_sc = (
    df_trips_av_sc_api
    .join(
        df_stops_av_sc.select("id", "stop_name"),
        left_on="stop_id",
        right_on="id",
        how="left"
    )
    .select("stop_id", "stop_name", "trip_id", "route_id", "trip_start_time", "service_date", "arrival_time")
    .sort(["trip_id", "service_date", "arrival_time"], descending=False)
    .with_columns(
        (
            (pl.col("service_date") + " " + pl.col("arrival_time"))
            .str.strptime(pl.Datetime, "%Y-%m-%d %H:%M:%S", strict=False)
            .alias("arrival_time")
        ),
        (
           pl.col("service_date")
           .str.strptime(pl.Date, "%Y-%m-%d")
        )          
    )
    
)
display(df_trips_av_sc)
# Out:
# shape: (2_814, 7)
# ┌──────────────┬──────────────┬──────────────┬──────────┬──────────────┬─────────────┬─────────────┐
# │ stop_id      ┆ stop_name    ┆ trip_id      ┆ route_id ┆ trip_start_t ┆ service_dat ┆ arrival_tim │
# │ ---          ┆ ---          ┆ ---          ┆ ---      ┆ ime          ┆ e           ┆ e           │
# │ str          ┆ str          ┆ str          ┆ str      ┆ ---          ┆ ---         ┆ ---         │
# │              ┆              ┆              ┆          ┆ str          ┆ date        ┆ datetime[μs │
# │              ┆              ┆              ┆          ┆              ┆             ┆ ]           │
# ╞══════════════╪══════════════╪══════════════╪══════════╪══════════════╪═════════════╪═════════════╡
# │ 8147-58c872f ┆ Avondale     ┆ 1075-01803-1 ┆ 18-202   ┆ 05:00:00     ┆ 2025-06-16  ┆ 2025-06-16  │
# │ 4            ┆ Police       ┆ 8000-2-0909b ┆          ┆              ┆             ┆ 05:06:37    │
# │              ┆ Station      ┆ f84          ┆          ┆              ┆             ┆             │
# │ 7133-173774e ┆ Pitt Street  ┆ 1075-01803-1 ┆ 18-202   ┆ 05:00:00     ┆ 2025-06-16  ┆ 2025-06-16  │
# │ a            ┆              ┆ 8000-2-0909b ┆          ┆              ┆             ┆ 05:26:31    │
# │              ┆              ┆ f84          ┆          ┆              ┆             ┆             │
# │ 8147-58c872f ┆ Avondale     ┆ 1075-01803-1 ┆ 18-202   ┆ 05:00:00     ┆ 2025-06-09  ┆ 2025-06-09  │
# │ 4            ┆ Police       ┆ 8000-2-a74f2 ┆          ┆              ┆             ┆ 05:06:37    │
# │              ┆ Station      ┆ 7ae          ┆          ┆              ┆             ┆             │
# │ 7133-173774e ┆ Pitt Street  ┆ 1075-01803-1 ┆ 18-202   ┆ 05:00:00     ┆ 2025-06-09  ┆ 2025-06-09  │
# │ a            ┆              ┆ 8000-2-a74f2 ┆          ┆              ┆             ┆ 05:26:31    │
# │              ┆              ┆ 7ae          ┆          ┆              ┆             ┆             │
# │ 8147-58c872f ┆ Avondale     ┆ 1075-01803-1 ┆ 18-202   ┆ 05:00:00     ┆ 2025-06-10  ┆ 2025-06-10  │
# │ 4            ┆ Police       ┆ 8000-2-a74f2 ┆          ┆              ┆             ┆ 05:06:37    │
# │              ┆ Station      ┆ 7ae          ┆          ┆              ┆             ┆             │
# │ …            ┆ …            ┆ …            ┆ …        ┆ …            ┆ …           ┆ …           │
# │ 7149-6d6d1e9 ┆ Symonds Stre ┆ 1278-02201-8 ┆ 22R-202  ┆ 22:35:00     ┆ 2025-06-16  ┆ 2025-06-16  │
# │ 9            ┆ et/Karangaha ┆ 1300-2-39bf8 ┆          ┆              ┆             ┆ 23:07:32    │
# │              ┆ pe Roa…      ┆ 491          ┆          ┆              ┆             ┆             │
# │ 8545-aed7c41 ┆ Rosebank     ┆ 1278-02201-8 ┆ 22R-202  ┆ 23:23:00     ┆ 2025-06-14  ┆ 2025-06-14  │
# │ 0            ┆ Road/Victor  ┆ 4180-2-582be ┆          ┆              ┆             ┆ 23:28:26    │
# │              ┆ Street       ┆ 196          ┆          ┆              ┆             ┆             │
# │ 7149-6d6d1e9 ┆ Symonds Stre ┆ 1278-02201-8 ┆ 22R-202  ┆ 23:23:00     ┆ 2025-06-14  ┆ 2025-06-14  │
# │ 9            ┆ et/Karangaha ┆ 4180-2-582be ┆          ┆              ┆             ┆ 23:52:14    │
# │              ┆ pe Roa…      ┆ 196          ┆          ┆              ┆             ┆             │
# │ 8545-aed7c41 ┆ Rosebank     ┆ 1278-02201-8 ┆ 22R-202  ┆ 23:23:00     ┆ 2025-06-15  ┆ 2025-06-15  │
# │ 0            ┆ Road/Victor  ┆ 4180-2-582be ┆          ┆              ┆             ┆ 23:28:26    │
# │              ┆ Street       ┆ 196          ┆          ┆              ┆             ┆             │
# │ 7149-6d6d1e9 ┆ Symonds Stre ┆ 1278-02201-8 ┆ 22R-202  ┆ 23:23:00     ┆ 2025-06-15  ┆ 2025-06-15  │
# │ 9            ┆ et/Karangaha ┆ 4180-2-582be ┆          ┆              ┆             ┆ 23:52:14    │
# │              ┆ pe Roa…      ┆ 196          ┆          ┆              ┆             ┆             │
# └──────────────┴──────────────┴──────────────┴──────────┴──────────────┴─────────────┴─────────────┘

# %%
df_trips_av_sc = (
    df_trips_av_sc
    .rename({
        "arrival_time": "start_datetime",
    })
    .with_columns(
        # Compute duration of trip from the starting bus stop to the final stop
        (
            pl.col("start_datetime")
            .diff()
            .over(["trip_id", "service_date"])
            .dt.total_minutes()
            .alias("trip_duration")
        ),
        # Get the final destination time in the same line as the starting stop
        (
            pl.col("start_datetime")
            .shift(-1)
            .over(["trip_id", "service_date"])
            .alias("arrival_datetime")
        )
    )
    .with_columns(
        # Get the trip duration in the line of the starting stop
        (
            pl.col("trip_duration")
            .shift(-1)
            .over(["trip_id", "service_date"])
        ).alias("trip_duration")
    )
    .drop_nulls(["trip_duration", "start_datetime", "arrival_datetime"])
    .sort(["start_datetime"], descending=False)
    .with_columns(
        (
            pl.col("start_datetime")
            .diff()
            .over(["route_id", "service_date"])
            .dt.total_minutes()
            .cast(pl.Int64)
            .alias("next_route_bus_waiting_time")
        ),
        (
            pl.col("start_datetime")
            .diff()
            .over(["service_date"])
            .dt.total_minutes()
            .cast(pl.Int64)
            .alias("next_bus_waiting_time")
        ),
        pl.col("service_date").dt.strftime("%A").alias("day_of_timeslot"),
        (
            pl.when(
                (pl.col("start_datetime").dt.hour() >= 11)
                & (pl.col("start_datetime").dt.hour() < 12)
            ).then(pl.lit("Start at 12"))
            .when(
                (pl.col("start_datetime").dt.hour() >= 10)
                & (pl.col("start_datetime").dt.hour() < 11)
            ).then(pl.lit("Start at 11"))
            .otherwise(pl.lit("Other"))
            .alias("time_slot")
        ),
        pl.col("start_datetime").dt.weekday().alias("weekday"),
        # Add walk time to the trip duration based on the route_id
        (
            pl.when(
                (pl.col("route_id") == "195-203")
            ).then(pl.col("trip_duration") + pl.lit(25))
            .when(
                (pl.col("route_id") == "22R-202")
            ).then(pl.col("trip_duration") + pl.lit(22))
            .when(
                (pl.col("route_id") == "18-202")
            ).then(pl.col("trip_duration") + pl.lit(17))
            .otherwise(pl.lit(-1))
            .alias("trip_duration")
        ),
    )
)

# %%
display(df_trips_av_sc)
# Out:
# shape: (1_407, 14)
# ┌────────────┬────────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬─────────┐
# │ stop_id    ┆ stop_name  ┆ trip_id   ┆ route_id ┆ … ┆ next_bus_ ┆ day_of_ti ┆ time_slot ┆ weekday │
# │ ---        ┆ ---        ┆ ---       ┆ ---      ┆   ┆ waiting_t ┆ meslot    ┆ ---       ┆ ---     │
# │ str        ┆ str        ┆ str       ┆ str      ┆   ┆ ime       ┆ ---       ┆ str       ┆ i8      │
# │            ┆            ┆           ┆          ┆   ┆ ---       ┆ str       ┆           ┆         │
# │            ┆            ┆           ┆          ┆   ┆ i64       ┆           ┆           ┆         │
# ╞════════════╪════════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═════════╡
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ null      ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-18000-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -a74f27ae ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8545-aed7c ┆ Rosebank   ┆ 1278-0220 ┆ 22R-202  ┆ … ┆ 2         ┆ Monday    ┆ Other     ┆ 1       │
# │ 410        ┆ Road/Victo ┆ 1-18120-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ r Street   ┆ -e485a8f4 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 12        ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-18900-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -a74f27ae ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8331-c2dad ┆ Avondale   ┆ 1095-1950 ┆ 195-203  ┆ … ┆ 15        ┆ Monday    ┆ Other     ┆ 1       │
# │ 3f5        ┆ Islamic    ┆ 7-18900-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Centre     ┆ -f1cd1a53 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 0         ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-19800-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -85f6d34b ┆          ┆   ┆           ┆           ┆           ┆         │
# │ …          ┆ …          ┆ …         ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …       │
# │ 8331-c2dad ┆ Avondale   ┆ 1095-1950 ┆ 195-203  ┆ … ┆ 0         ┆ Monday    ┆ Other     ┆ 1       │
# │ 3f5        ┆ Islamic    ┆ 7-80100-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Centre     ┆ -06ff451d ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8545-aed7c ┆ Rosebank   ┆ 1278-0220 ┆ 22R-202  ┆ … ┆ 2         ┆ Monday    ┆ Other     ┆ 1       │
# │ 410        ┆ Road/Victo ┆ 1-81300-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ r Street   ┆ -39bf8491 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 12        ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-81900-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -975633d0 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 15        ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-82800-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -975633d0 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 15        ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-83700-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -975633d0 ┆          ┆   ┆           ┆           ┆           ┆         │
# └────────────┴────────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴─────────┘

# %%
import plotly.express as px

fig = px.box(df_trips_av_sc, x="day_of_timeslot", y="trip_duration", color="route_id")
fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default
fig.show()

# %%
import plotly.express as px

fig = px.box(df_trips_av_sc, x="day_of_timeslot", y="next_bus_waiting_time", color="route_id")
fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default
fig.show()

# %% [markdown]
# # Write in parquet file

# %%
df_trips_av_sc.write_parquet("data/at_gtfs_trips_av_sc.parquet")

# %%
df_trips_av_sc.write_csv("data/at_gtfs_trips_av_sc.csv")

# %%
display(pl.read_parquet("data/at_gtfs_trips_av_sc.parquet"))
# Out:
# shape: (1_519, 14)
# ┌────────────┬────────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬─────────┐
# │ stop_id    ┆ stop_name  ┆ trip_id   ┆ route_id ┆ … ┆ next_bus_ ┆ day_of_ti ┆ time_slot ┆ weekday │
# │ ---        ┆ ---        ┆ ---       ┆ ---      ┆   ┆ waiting_t ┆ meslot    ┆ ---       ┆ ---     │
# │ str        ┆ str        ┆ str       ┆ str      ┆   ┆ ime       ┆ ---       ┆ str       ┆ i8      │
# │            ┆            ┆           ┆          ┆   ┆ ---       ┆ str       ┆           ┆         │
# │            ┆            ┆           ┆          ┆   ┆ i64       ┆           ┆           ┆         │
# ╞════════════╪════════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═════════╡
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ null      ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-18000-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -a74f27ae ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8545-aed7c ┆ Rosebank   ┆ 1278-0220 ┆ 22R-202  ┆ … ┆ 2         ┆ Monday    ┆ Other     ┆ 1       │
# │ 410        ┆ Road/Victo ┆ 1-18120-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ r Street   ┆ -e485a8f4 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 12        ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-18900-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -a74f27ae ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8331-c2dad ┆ Avondale   ┆ 1095-1950 ┆ 195-203  ┆ … ┆ 15        ┆ Monday    ┆ Other     ┆ 1       │
# │ 3f5        ┆ Islamic    ┆ 7-18900-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Centre     ┆ -f1cd1a53 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 0         ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-19800-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -85f6d34b ┆          ┆   ┆           ┆           ┆           ┆         │
# │ …          ┆ …          ┆ …         ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …       │
# │ 8331-c2dad ┆ Avondale   ┆ 1095-1950 ┆ 195-203  ┆ … ┆ 0         ┆ Monday    ┆ Other     ┆ 1       │
# │ 3f5        ┆ Islamic    ┆ 7-80100-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Centre     ┆ -06ff451d ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8545-aed7c ┆ Rosebank   ┆ 1278-0220 ┆ 22R-202  ┆ … ┆ 2         ┆ Monday    ┆ Other     ┆ 1       │
# │ 410        ┆ Road/Victo ┆ 1-81300-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ r Street   ┆ -39bf8491 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 12        ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-81900-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -975633d0 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 15        ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-82800-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -975633d0 ┆          ┆   ┆           ┆           ┆           ┆         │
# │ 8147-58c87 ┆ Avondale   ┆ 1075-0180 ┆ 18-202   ┆ … ┆ 15        ┆ Monday    ┆ Other     ┆ 1       │
# │ 2f4        ┆ Police     ┆ 3-83700-2 ┆          ┆   ┆           ┆           ┆           ┆         │
# │            ┆ Station    ┆ -975633d0 ┆          ┆   ┆           ┆           ┆           ┆         │
# └────────────┴────────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴─────────┘

# %% [markdown]
# # Get data from cloud torage

# %%
from io import BytesIO
from google.cloud import storage
import polars as pl
from loguru import logger

# %%
def read_parquet_from_gcs(bucket_name: str, blob_name: str) -> pl.DataFrame:
    """
    Reads a Parquet file from Google Cloud Storage into a Polars DataFrame.

    Args:
        bucket_name: The name of the GCS bucket.
        blob_name: The path to the Parquet file within the bucket.

    Returns:
        A Polars DataFrame containing the data from the Parquet file.
    """
    try:
        client = storage.Client()  # Assumes GOOGLE_APPLICATION_CREDENTIALS is set
        bucket = client.bucket(bucket_name)
        blob = bucket.blob(blob_name)

        # Download the blob's content as bytes
        parquet_bytes = blob.download_as_bytes()

        # Read the Parquet data from the bytes
        df = pl.read_parquet(BytesIO(parquet_bytes))
        
        logger.info(f"Successfully read Parquet file '{blob_name}' from GCS bucket '{bucket_name}'.")
        return df
    except Exception as e:
        logger.error(f"Error reading Parquet file '{blob_name}' from GCS bucket '{bucket_name}': {e}")
        raise

# %%
bucket_name = "at-bus-open-data"
    # Example blob name, replace with an actual blob path from your GCS
blob_name = "2025-06-17/trips_7149-6d6d1e99.parquet" 

try:
    df_from_gcs = read_parquet_from_gcs(bucket_name, blob_name)
    display(df_from_gcs)
except Exception as e:
    print(f"Failed to read data: {e}")
# Out:
# 2025-06-18 17:52:24.481 | INFO     | __main__:read_parquet_from_gcs:23 - Successfully read Parquet file 'at-bus/2025-06-17/trips_7149-6d6d1e99.parquet' from GCS bucket 'pne-open-data'.
# shape: (707, 17)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ type     ┆ id        ┆ arrival_t ┆ departure ┆ … ┆ trip_head ┆ trip_id   ┆ trip_star ┆ api_date_ │
# │ ---      ┆ ---       ┆ ime       ┆ _time     ┆   ┆ sign      ┆ ---       ┆ t_time    ┆ ingestion │
# │ str      ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │          ┆           ┆ str       ┆ str       ┆   ┆ str       ┆           ┆ str       ┆ date      │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ stoptrip ┆ stop:7149 ┆ 05:23:03  ┆ 05:23:03  ┆ … ┆ Waikowhai ┆ 27-02707- ┆ 04:55:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ To        ┆ 17700-2-2 ┆           ┆ 7         │
# │          ┆ _trip:27- ┆           ┆           ┆   ┆ Britomart ┆ b57ccb3   ┆           ┆           │
# │          ┆ 027…      ┆           ┆           ┆   ┆ Via Hil…  ┆           ┆           ┆           │
# │ stoptrip ┆ stop:7149 ┆ 05:34:08  ┆ 05:34:08  ┆ … ┆ Waikowhai ┆ 1283-0270 ┆ 05:05:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ To        ┆ 5-18300-2 ┆           ┆ 7         │
# │          ┆ _trip:128 ┆           ┆           ┆   ┆ Britomart ┆ -927d2e0c ┆           ┆           │
# │          ┆ 3-0…      ┆           ┆           ┆   ┆ Via Mt …  ┆           ┆           ┆           │
# │ stoptrip ┆ stop:7149 ┆ 05:34:34  ┆ 05:34:34  ┆ … ┆ New Lynn  ┆ 24-02403- ┆ 05:00:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ And Block ┆ 18000-2-0 ┆           ┆ 7         │
# │          ┆ _trip:24- ┆           ┆           ┆   ┆ house Bay ┆ d6f00a1   ┆           ┆           │
# │          ┆ 024…      ┆           ┆           ┆   ┆ To…       ┆           ┆           ┆           │
# │ stoptrip ┆ stop:7149 ┆ 05:36:32  ┆ 05:36:32  ┆ … ┆ Rosebank  ┆ 1278-0220 ┆ 05:02:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ Rd To     ┆ 1-18120-2 ┆           ┆ 7         │
# │          ┆ _trip:127 ┆           ┆           ┆   ┆ City      ┆ -e485a8f4 ┆           ┆           │
# │          ┆ 8-0…      ┆           ┆           ┆   ┆ Centre    ┆           ┆           ┆           │
# │          ┆           ┆           ┆           ┆   ┆ Via…      ┆           ┆           ┆           │
# │ stoptrip ┆ stop:7149 ┆ 05:37:02  ┆ 05:37:02  ┆ … ┆ Lynfield  ┆ 1281-0250 ┆ 05:05:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ To City   ┆ 3-18300-2 ┆           ┆ 7         │
# │          ┆ _trip:128 ┆           ┆           ┆   ┆ Centre    ┆ -cbcd1590 ┆           ┆           │
# │          ┆ 1-0…      ┆           ┆           ┆   ┆ Via Do…   ┆           ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ stoptrip ┆ stop:7149 ┆ 23:37:32  ┆ 23:37:32  ┆ … ┆ New Lynn  ┆ 1277-0220 ┆ 23:07:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ To City   ┆ 3-83220-2 ┆           ┆ 7         │
# │          ┆ _trip:127 ┆           ┆           ┆   ┆ Centre    ┆ -f9fb00ea ┆           ┆           │
# │          ┆ 7-0…      ┆           ┆           ┆   ┆ Via Ne…   ┆           ┆           ┆           │
# │ stoptrip ┆ stop:7149 ┆ 23:40:58  ┆ 23:40:58  ┆ … ┆ Botany To ┆ 1153-0700 ┆ 23:00:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ Britomart ┆ 5-82800-2 ┆           ┆ 7         │
# │          ┆ _trip:115 ┆           ┆           ┆   ┆ Via       ┆ -70d1384b ┆           ┆           │
# │          ┆ 3-0…      ┆           ┆           ┆   ┆ Panmur…   ┆           ┆           ┆           │
# │ stoptrip ┆ stop:7149 ┆ 23:41:28  ┆ 23:41:28  ┆ … ┆ Glen      ┆ 1285-0750 ┆ 23:15:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ Innes To  ┆ 1-83700-2 ┆           ┆ 7         │
# │          ┆ _trip:128 ┆           ┆           ┆   ┆ Wynyard   ┆ -0770861e ┆           ┆           │
# │          ┆ 5-0…      ┆           ┆           ┆   ┆ Quarter … ┆           ┆           ┆           │
# │ stoptrip ┆ stop:7149 ┆ 23:42:34  ┆ 23:42:34  ┆ … ┆ New Lynn  ┆ 24-02403- ┆ 23:10:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ And Block ┆ 83400-2-4 ┆           ┆ 7         │
# │          ┆ _trip:24- ┆           ┆           ┆   ┆ house Bay ┆ c8537cf   ┆           ┆           │
# │          ┆ 024…      ┆           ┆           ┆   ┆ To…       ┆           ┆           ┆           │
# │ stoptrip ┆ stop:7149 ┆ 24:04:36  ┆ 24:04:36  ┆ … ┆ Lynfield  ┆ 1281-0250 ┆ 23:33:00  ┆ 2025-06-1 │
# │          ┆ -6d6d1e99 ┆           ┆           ┆   ┆ To City   ┆ 3-84780-2 ┆           ┆ 7         │
# │          ┆ _trip:128 ┆           ┆           ┆   ┆ Centre    ┆ -07ac73d3 ┆           ┆           │
# │          ┆ 1-0…      ┆           ┆           ┆   ┆ Via Do…   ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
